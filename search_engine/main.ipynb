# %%
# pip install pdfplumber nltk numpy rapidfuzz

# %%
import pdfplumber
import glob
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import regex as re
import base64
import numpy as np
from multiprocessing import Pool, cpu_count
import pickle
import os
from rapidfuzz import fuzz
from rapidfuzz import process
import json
from custom_bm25 import BM25Okapi

# %%
keywords_to_remove = (
    'Score:', 'Episodes', 'Status', 'Aired', 'Premiered', 'Broadcast', 'Licensors',
    'Source', 'Duration', 'Characters', 'Anime Details', 'Japanese', 'Main Supporting',
    'Main Main', 'None', 'Demographic', 'Genres', 'Studios',
    'Data source: MyAnimeList', 'Supporting Supporting', '[Written by MAL Rewrite]'
)

animes_corpus = []
animes_json = []

pdfs = glob.glob(r'C:\Users\menno\Desktop\AI-location\animes_search_engine\pdf_transformer\pdfs\*.pdf')

for index, pdf in enumerate(pdfs):
    with pdfplumber.open(pdf) as f:
        
        txt = ''.join(page.extract_text() for page in f.pages)
        list_sentences = txt.split('\n')
        
        # Filter sentences based on keywords
        filtered_sentences = [
            i for i in list_sentences if not any(i.startswith(keyword) for keyword in keywords_to_remove)
        ]
        animes_corpus.append('\n'.join(filtered_sentences))

        # Extract specific fields
        def find_value(key, sentences):
            for i, sentence in enumerate(sentences):
                if sentence.lower().startswith(key.lower()):
                    return i
            return None

        score_index = find_value('score:', list_sentences)
        genres_index = find_value('Genres', list_sentences)
        description_end_index = find_value('Anime Details',list_sentences)
        demographic_index = find_value('Demographic', list_sentences)
        studios_index = find_value('Studios', list_sentences)
        premiered_index = find_value('Premiered', list_sentences)

        # Handling fields
        def extract_field_value(index, label):
            if index is not None:
                parts = list_sentences[index].split(label)
                return parts[1].strip() if len(parts) > 1 else list_sentences[index + 1].strip()
            return None

        demographic_value = extract_field_value(demographic_index, 'Demographic')
        studios_value = extract_field_value(studios_index, 'Studios')
        premiered_value = extract_field_value(premiered_index, 'Premiered')

        # JSON format output per doc
        animes_json.append({
            'doc_name': os.path.basename(pdf),
            'title': f.metadata.get('Title'),
            # 'image':base64.b64encode(f.images[0]["stream"].get_data()).decode('utf-8')  ,
            'score': list_sentences[score_index].split()[1],
            'description': '\n'.join(list_sentences[score_index + 1:description_end_index]) if score_index is not None and description_end_index is not None else None,
            'genres': list_sentences[genres_index].split()[1:] if genres_index else None,
            'demographic': demographic_value,
            'studios': studios_value,
            'premiered': premiered_value
        })
        
    print(f'anime {index + 1}')
# Out:
# anime 1
# anime 2
# anime 3
# anime 4
# anime 5
# anime 6
# anime 7
# anime 8
# anime 9
# anime 10
# anime 11
# anime 12
# anime 13
# anime 14
# anime 15
# anime 16
# anime 17
# anime 18
# anime 19
# anime 20
# anime 21
# anime 22
# anime 23
# anime 24
# anime 25
# anime 26
# anime 27
# anime 28
# anime 29
# anime 30
# anime 31
# anime 32
# anime 33
# anime 34
# anime 35
# anime 36
# anime 37
# anime 38
# anime 39
# anime 40
# anime 41
# anime 42
# anime 43
# anime 44
# anime 45
# anime 46
# anime 47
# anime 48
# anime 49
# anime 50
# anime 51
# anime 52
# anime 53
# anime 54
# anime 55
# anime 56
# anime 57
# anime 58
# anime 59
# anime 60
# anime 61
# anime 62
# anime 63
# anime 64
# anime 65
# anime 66
# anime 67
# anime 68
# anime 69
# anime 70
# anime 71
# anime 72
# anime 73
# anime 74
# anime 75
# anime 76
# anime 77
# anime 78
# anime 79
# anime 80
# anime 81
# anime 82
# anime 83
# anime 84
# anime 85
# anime 86
# anime 87
# anime 88
# anime 89
# anime 90
# anime 91
# anime 92
# anime 93
# anime 94
# anime 95
# anime 96
# anime 97
# anime 98
# anime 99
# anime 100
# anime 101
# anime 102
# anime 103
# anime 104
# anime 105
# anime 106
# anime 107
# anime 108
# anime 109
# anime 110
# anime 111
# anime 112
# anime 113
# anime 114
# anime 115
# anime 116
# anime 117
# anime 118
# anime 119
# anime 120
# anime 121
# anime 122
# anime 123
# anime 124
# anime 125
# anime 126
# anime 127
# anime 128
# anime 129
# anime 130
# anime 131
# anime 132
# anime 133
# anime 134
# anime 135
# anime 136
# anime 137
# anime 138
# anime 139
# anime 140
# anime 141
# anime 142
# anime 143
# anime 144
# anime 145
# anime 146
# anime 147
# anime 148
# anime 149
# anime 150
# anime 151
# anime 152
# anime 153
# anime 154
# anime 155
# anime 156
# anime 157
# anime 158
# anime 159
# anime 160
# anime 161
# anime 162
# anime 163
# anime 164
# anime 165
# anime 166
# anime 167
# anime 168
# anime 169
# anime 170
# anime 171
# anime 172
# anime 173
# anime 174
# anime 175
# anime 176
# anime 177
# anime 178
# anime 179
# anime 180
# anime 181
# anime 182
# anime 183
# anime 184
# anime 185
# anime 186
# anime 187
# anime 188
# anime 189
# anime 190
# anime 191
# anime 192
# anime 193
# anime 194
# anime 195
# anime 196
# anime 197
# anime 198
# anime 199
# anime 200
# anime 201
# anime 202
# anime 203
# anime 204
# anime 205
# anime 206
# anime 207
# anime 208
# anime 209
# anime 210
# anime 211
# anime 212
# anime 213
# anime 214
# anime 215
# anime 216
# anime 217
# anime 218
# anime 219
# anime 220
# anime 221
# anime 222
# anime 223
# anime 224
# anime 225
# anime 226
# anime 227
# anime 228
# anime 229
# anime 230
# anime 231
# anime 232
# anime 233
# anime 234
# anime 235
# anime 236
# anime 237
# anime 238
# anime 239
# anime 240
# anime 241
# anime 242
# anime 243
# anime 244
# anime 245
# anime 246
# anime 247
# anime 248
# anime 249
# anime 250
# anime 251
# anime 252
# anime 253
# anime 254
# anime 255
# anime 256
# anime 257
# anime 258
# anime 259
# anime 260
# anime 261
# anime 262
# anime 263
# anime 264
# anime 265
# anime 266
# anime 267
# anime 268
# anime 269
# anime 270
# anime 271
# anime 272
# anime 273
# anime 274
# anime 275
# anime 276
# anime 277
# anime 278
# anime 279
# anime 280
# anime 281
# anime 282
# anime 283
# anime 284
# anime 285
# anime 286
# anime 287
# anime 288
# anime 289
# anime 290
# anime 291
# anime 292
# anime 293
# anime 294
# anime 295
# anime 296
# anime 297
# anime 298
# anime 299
# anime 300
# anime 301
# anime 302
# anime 303
# anime 304
# anime 305
# anime 306
# anime 307
# anime 308
# anime 309
# anime 310
# anime 311
# anime 312
# anime 313
# anime 314
# anime 315
# anime 316
# anime 317
# anime 318
# anime 319
# anime 320
# anime 321
# anime 322
# anime 323
# anime 324
# anime 325
# anime 326
# anime 327
# anime 328
# anime 329
# anime 330
# anime 331
# anime 332
# anime 333
# anime 334
# anime 335
# anime 336
# anime 337
# anime 338
# anime 339
# anime 340
# anime 341
# anime 342
# anime 343
# anime 344
# anime 345
# anime 346
# anime 347
# anime 348
# anime 349
# anime 350
# anime 351
# anime 352
# anime 353
# anime 354
# anime 355
# anime 356
# anime 357
# anime 358
# anime 359
# anime 360
# anime 361
# anime 362
# anime 363
# anime 364
# anime 365
# anime 366
# anime 367
# anime 368
# anime 369
# anime 370
# anime 371
# anime 372
# anime 373
# anime 374
# anime 375
# anime 376
# anime 377
# anime 378
# anime 379
# anime 380
# anime 381
# anime 382
# anime 383
# anime 384
# anime 385
# anime 386
# anime 387
# anime 388
# anime 389
# anime 390
# anime 391
# anime 392
# anime 393
# anime 394
# anime 395
# anime 396
# anime 397
# anime 398
# anime 399
# anime 400

# %%
# print(animes_corpus)

# %%
# Save animes_json to a file
with open('animes_data.json', 'w', encoding='utf-8') as json_file:
    json.dump(animes_json, json_file, ensure_ascii=False, indent=4)

print("animes_json has been saved to 'animes_data.json'")

# %%
nltk.download('stopwords')
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
ps = PorterStemmer()
stop_words = set(stopwords.words('english'))

# %%
#lower, remove punctuations , remove stop words , tokenize input
def filter_text(input_string , string , stop_words):
    tokenized_input = input_string.translate(str.maketrans('', '', string.punctuation)).lower().split()
    filterd_tokenized_input = [w for w in tokenized_input if not w in stop_words]
    filterd_tokenized_input = [ps.stem(lemmatizer.lemmatize(i)) for i in filterd_tokenized_input ]
    return filterd_tokenized_input

# %%
tokenized_cleaned_corpus = []
for doc in animes_corpus:
    clean_doc = filter_text(doc , string , stop_words)
    tokenized_cleaned_corpus.append(clean_doc)

# %%
print(tokenized_cleaned_corpus)

# %%
def flatten_and_remove_duplicates(nested_list):
    # Flatten the list using recursion
    def flatten(lst):
        for item in lst:
            if isinstance(item, list):
                yield from flatten(item)
            else:
                yield item

    # Flatten the list and convert it to a set to remove duplicates
    flattened = list(flatten(nested_list))
    unique_items = []
    for item in flattened:
        if len(item) > 2 and item not in unique_items:  # Skip items with length 1 and 2
            unique_items.append(item)

    return unique_items

# flatten_corpus = flatten_and_remove_duplicates(tokenized_cleaned_corpus)

list_to_flatten = []

for doc in animes_corpus:
    clean_doc = doc.translate(str.maketrans('', '', string.punctuation)).lower().split()
    list_to_flatten.append(clean_doc)

flatten_corpus = flatten_and_remove_duplicates(list_to_flatten)

# %%
print(flatten_corpus)

# %%
with open('flatten_corpus.json', 'w', encoding='utf-8') as json_file:
    json.dump(flatten_corpus, json_file, ensure_ascii=False)

# %%
bm25 = BM25Okapi(tokenized_cleaned_corpus)

# %%
# # # save model
file_name = r"models\model.pkl"

os.makedirs(os.path.dirname(file_name),exist_ok=True)

with open(file_name, 'wb') as file:
    pickle.dump(bm25, file)

# %%
#loading the bm25 model
with open(r"models\model.pkl", 'rb') as file:
    model = pickle.load(file)

# loading the flatten corpus for the fuzzy search
with open('flatten_corpus.json', 'r', encoding='utf-8') as json_file:
    flatten_corpus = json.load(json_file)

# loading the the pdfs jsons : results
with open('animes_data.json', 'r', encoding='utf-8') as json_file:
    animes_json = json.load(json_file)

doc_names = [anime['doc_name'] for anime in animes_json]

# %%
query = "demn slaer"

tokenized_query = query.translate(str.maketrans('', '', string.punctuation)).lower().split()

fuzzy_tokenized_query_list = []

for q in tokenized_query:
    if len(q) <= 2:
        q=q
    else :
        # print(process.extract(q,flatten_corpus,limit=3))
        fuzzy_query = process.extractOne(q, flatten_corpus)
        q = fuzzy_query[0] if fuzzy_query[1] > 79 else q
        
    fuzzy_tokenized_query_list.append(q)

fuzzy_tokenized_query = ' '.join(fuzzy_tokenized_query_list)
print(fuzzy_tokenized_query)

fuzzy_tokenized_cleaned_query = filter_text(fuzzy_tokenized_query , string , stop_words)
print(fuzzy_tokenized_cleaned_query)

result = model.get_top_n(fuzzy_tokenized_cleaned_query , doc_names, n = 100)
print(result)
# Out:
# demon slayer
# ['demon', 'slayer']
# [{'doc': 'anime146.pdf', 'score': 13.078838367494392}, {'doc': 'anime342.pdf', 'score': 12.080155965801346}, {'doc': 'anime258.pdf', 'score': 11.165404061549397}, {'doc': 'anime399.pdf', 'score': 11.151680001501479}, {'doc': 'anime297.pdf', 'score': 10.586749231223745}, {'doc': 'anime279.pdf', 'score': 5.274277379045504}, {'doc': 'anime303.pdf', 'score': 4.748565388095071}, {'doc': 'anime354.pdf', 'score': 4.4628744687784945}, {'doc': 'anime189.pdf', 'score': 4.418005901599136}, {'doc': 'anime229.pdf', 'score': 3.8374414040154665}, {'doc': 'anime355.pdf', 'score': 3.758666473788764}, {'doc': 'anime298.pdf', 'score': 3.7299533175405677}, {'doc': 'anime162.pdf', 'score': 3.68306066860654}, {'doc': 'anime358.pdf', 'score': 3.619357521135475}, {'doc': 'anime263.pdf', 'score': 3.610436518018125}, {'doc': 'anime275.pdf', 'score': 3.1021169508605273}, {'doc': 'anime306.pdf', 'score': 2.742076046239085}, {'doc': 'anime184.pdf', 'score': 2.742076046239085}, {'doc': 'anime341.pdf', 'score': 2.6720476434517186}, {'doc': 'anime247.pdf', 'score': 2.6526917391300064}, {'doc': 'anime2.pdf', 'score': 2.5779933806044437}, {'doc': 'anime73.pdf', 'score': 2.542199896478564}, {'doc': 'anime363.pdf', 'score': 2.5334062899369902}, {'doc': 'anime349.pdf', 'score': 2.4569187595297315}, {'doc': 'anime76.pdf', 'score': 2.3927058161899373}, {'doc': 'anime188.pdf', 'score': 2.3771736262488674}]

# %%
# query = "one one one one one"
# tokenized_cleaned_query = filter_text(query , string , stop_words)

# fuzzy_tokenized_cleaned_query = []

# for q in tokenized_cleaned_query:
#     if len(q) <= 2:
#         q=q
#     else :
#         q = process.extractOne(q, flatten_corpus)[0]
#         print(process.extract(q,flatten_corpus,limit=2))
#     fuzzy_tokenized_cleaned_query.append(q)

# print(fuzzy_tokenized_cleaned_query)


# result = model.get_top_n(fuzzy_tokenized_cleaned_query , doc_names, n = len(doc_names))
# print(result)
